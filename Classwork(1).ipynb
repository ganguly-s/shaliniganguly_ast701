# %%
import numpy as np
from matplotlib import pyplot as p

hcont=6.625e-27
ccont=3.e10
kcont=1.381e-16
rcont=8.314472e7
Gcont=6.67e-8
Msun=1.989e33
Lsun=3.827e33
rsun=6.96e10
yr=365.*24.*3600
pi=3.1415926
au=1.49598e13
pc=3.085678e18
ev=1.6022e-12

def BlackbodyBnu(Temperature, nu):
    return 2.*hcont*nu**3/ccont**2/(np.exp(hcont*nu/kcont/Temperature)-1)

hnu=10.**np.arange(-1,4,0.1)*ev 

# white dwarf a single blackbody at 1e4 K

Bnu=np.array(hnu.size)
Temperature=1.e4

Bnu=BlackbodyBnu(Temperature,hnu/hcont)

p.plot(np.log10(hnu/ev),np.log10(Bnu),label='white dwarf BB radiation')
p.ylim(np.log10(Bnu.max())-4.,np.log10(Bnu.max()))
p.xlabel(r'Log$_{10}(h\nu/ev)$')
p.legend()
p.show()
# Out:
# /Users/ganguly93/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:31: RuntimeWarning: divide by zero encountered in log10

# %%
SED = np.pi*Bnu*4*np.pi* (1e9**2)
p.plot(np.log10(hnu/ev),np.log10(SED),label='white dwarf spectrum')
p.ylim(10.,18.5)
p.xlabel(r'Log$_{10}(h\nu/ev)$')
dr = (100*1e9 - 1e9)/49
SED0 = []
m = 0
def T(r):
    return ((Gcont*Msun*1e-9*Msun/yr/8/np.pi/5.67e-5)**0.25)*(r**-0.75)
for j in range(50):
    S = 0
    for i in range(50):
        r = 1e9 + i*dr
        temp = T(r)
        Bnu=np.array(hnu.size)
        Bnu=BlackbodyBnu(temp,hnu[j]/hcont)
        S += 2*np.pi*Bnu*2*np.pi*r*dr
    SED0.append(S)
m = np.max(SED0)
p.plot(np.log10(hnu/ev),np.log10(SED0),label='white dwarf accretion spectrum')
p.xlabel(r'Log$_{10}(h\nu/ev)$')
p.legend()
p.show()
# Out:
# /Users/ganguly93/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
#
# /Users/ganguly93/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in log10

# %%
dr = (100*1e9 - 1e9)/49
SED0 = []
m = 0
def T(r):
    return ((Gcont*Msun*1e-9*Msun/yr/8/np.pi/5.67e-5)**0.25)*(r**-0.75)
for j in range(50):
    S = 0
    for i in range(50):
        r = 1e9 + i*dr
        temp = T(r)
        Bnu=np.array(hnu.size)
        Bnu=BlackbodyBnu(temp,hnu[j]/hcont)
        S += 2*np.pi*Bnu*2*np.pi*r*dr
    SED0.append(S)
m = np.max(SED0)
p.plot(np.log10(hnu/ev),np.log10(SED0),label='white dwarf')
p.xlabel(r'Log$_{10}(h\nu/ev)$')
dr = (100*1e6 - 1e6)/49
SED0 = []
m = 0
def T(r):
    return ((Gcont*Msun*1e-9*Msun/yr/8/np.pi/5.67e-5)**0.25)*(r**-0.75)
for j in range(50):
    S = 0
    for i in range(50):
        r = 1e6 + i*dr
        temp = T(r)
        Bnu=np.array(hnu.size)
        Bnu=BlackbodyBnu(temp,hnu[j]/hcont)
        S += 2*np.pi*Bnu*2*np.pi*r*dr
    SED0.append(S)
m = np.max(SED0)
p.plot(np.log10(hnu/ev),np.log10(SED0),label='neutron star')
p.ylim(10,20)
p.xlabel(r'Log$_{10}(h\nu/ev)$')
p.title('Accretion spectrum')
p.legend()
p.show()
# Out:
# /Users/ganguly93/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()

# %%
rs = 2*Gcont*Msun/ccont/ccont
#non-rotating black hole
dr = (100*3*rs - 3*rs)/49
SED0 = []
m = 0
def T(r):
    return ((Gcont*Msun*1e-9*Msun/yr/8/np.pi/5.67e-5)**0.25)*(r**-0.75)
for j in range(50):
    S = 0
    for i in range(50):
        r = 3*rs + i*dr
        temp = T(r)
        Bnu=np.array(hnu.size)
        Bnu=BlackbodyBnu(temp,hnu[j]/hcont)
        S += 2*np.pi*Bnu*2*np.pi*r*dr
    SED0.append(S)
m = np.max(SED0)
p.plot(np.log10(hnu/ev),np.log10(SED0),label='non-rotating BH')
p.xlabel(r'Log$_{10}(h\nu/ev)$')
#prograte spinning BH
dr = (100*0.5*rs - 0.5*rs)/49
SED0 = []
m = 0
def T(r):
    return ((Gcont*Msun*1e-9*Msun/yr/8/np.pi/5.67e-5)**0.25)*(r**-0.75)
for j in range(50):
    S = 0
    for i in range(50):
        r = 0.5*rs + i*dr
        temp = T(r)
        Bnu=np.array(hnu.size)
        Bnu=BlackbodyBnu(temp,hnu[j]/hcont)
        S += 2*np.pi*Bnu*2*np.pi*r*dr
    SED0.append(S)
m = np.max(SED0)
p.plot(np.log10(hnu/ev),np.log10(SED0),label='prograte spinning BH')
p.xlabel(r'Log$_{10}(h\nu/ev)$')
#retrograte spinning BH
dr = (100*4.5*rs - 4.5*rs)/49
SED0 = []
m = 0
def T(r):
    return ((Gcont*Msun*1e-9*Msun/yr/8/np.pi/5.67e-5)**0.25)*(r**-0.75)
for j in range(50):
    S = 0
    for i in range(50):
        r = 4.5*rs + i*dr
        temp = T(r)
        Bnu=np.array(hnu.size)
        Bnu=BlackbodyBnu(temp,hnu[j]/hcont)
        S += 2*np.pi*Bnu*2*np.pi*r*dr
    SED0.append(S)
m = np.max(SED0)
p.plot(np.log10(hnu/ev),np.log10(SED0),label='retrograte spinning BH')
p.ylim(12,20)
p.xlabel(r'Log$_{10}(h\nu/ev)$')
p.title('Accretion spectrum')
p.legend()
p.show()
